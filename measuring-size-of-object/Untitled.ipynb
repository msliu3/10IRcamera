# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Sep 26 22:23:09 2019

@author: neo
"""

import numpy as np
import cv2 as cv

img = cv.imread('enlarge-original.jpg',0)
img2 = cv.imread('enlarge-original.jpg',1)

ret,thresh = cv.threshold(img,106,255,0)
print(ret)
contours,hierarchy = cv.findContours(thresh,1,2)


cnt = contours[0]
M = cv.moments(cnt)
print(M,len(contours))

area = cv.contourArea(cnt)
print(area)
epsilon = 0.1*cv.arcLength(cnt,True)
approx = cv.approxPolyDP(cnt,epsilon,True)

# =============================================================================
# x,y,w,h = cv.boundingRect(cnt)
# cv.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
# =============================================================================

# =============================================================================
# x,y,w,h = cv.boundingRect(contours[1])
# cv.rectangle(img2,(x,y),(x+w,y+h),(0,255,0),2)
# =============================================================================

hull = cv.convexHull(contours[0])
foot = []
for a in hull:
    if a[0][1]>100:
        foot.append(a)
print(foot)

rect = cv.minAreaRect(np.array(foot))
box = cv.boxPoints(rect)
box = np.int0(box)
cv.drawContours(img2,[box],0,(0,0,255),2)

cv.drawContours(img2,foot,-1,(255,0,0),3)
x,y,w,h = cv.boundingRect(np.array(foot))
cv.rectangle(img2,(x,y),(x+w,y+h),(0,0,255),2)

hull = cv.convexHull(contours[1])
foot = []
for a in hull:
    if a[0][1]>100:
        foot.append(a)
print(foot)

rect = cv.minAreaRect(np.array(foot))
box = cv.boxPoints(rect)
box = np.int0(box)
cv.drawContours(img2,[box],0,(0,0,255),2)

cv.drawContours(img2,foot,-1,(255,0,0),3)
x,y,w,h = cv.boundingRect(np.array(foot))
cv.rectangle(img2,(x,y),(x+w,y+h),(0,0,255),2)

cv.imshow("hehe",img2)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 106.0
# {'m00': 13617.5, 'm10': 2988220.6666666665, 'm01': 1547831.6666666665, 'm20': 667431248.0833333, 'm11': 356207719.7083333, 'm02': 237847998.0833333, 'm30': 151869164716.5, 'm21': 83442950535.31667, 'm12': 56129069507.416664, 'm03': 40553034160.200005, 'mu20': 11696880.34374988, 'mu11': 16551940.390951693, 'mu02': 61913878.87377864, 'mu30': 274704040.2243042, 'mu21': 315142802.2091098, 'mu12': 173017488.93320656, 'mu03': -556801561.5296631, 'nu20': 0.06307761721688135, 'nu11': 0.08925943751617245, 'nu02': 0.33388218373109796, 'nu30': 0.012694675004642681, 'nu21': 0.014563438713279926, 'nu12': 0.007995516885492441, 'nu03': -0.02573101895379861} 2
# 13617.5
# [array([[307, 197]], dtype=int32), array([[306, 201]], dtype=int32), array([[303, 207]], dtype=int32), array([[273, 215]], dtype=int32), array([[263, 217]], dtype=int32), array([[255, 217]], dtype=int32), array([[204, 207]], dtype=int32), array([[200, 206]], dtype=int32), array([[197, 203]], dtype=int32), array([[194, 196]], dtype=int32), array([[190, 185]], dtype=int32), array([[189, 182]], dtype=int32), array([[307, 188]], dtype=int32)]
# [array([[172, 188]], dtype=int32), array([[171, 192]], dtype=int32), array([[170, 195]], dtype=int32), array([[129, 224]], dtype=int32), array([[123, 225]], dtype=int32), array([[120, 225]], dtype=int32), array([[113, 224]], dtype=int32), array([[ 94, 218]], dtype=int32), array([[ 92, 217]], dtype=int32), array([[ 91, 215]], dtype=int32), array([[ 90, 211]], dtype=int32), array([[172, 187]], dtype=int32)]

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Sep 26 22:23:09 2019

@author: neo
"""

import numpy as np
import cv2 as cv

img = cv.imread('enlarge-original.jpg',0)
img2 = cv.imread('enlarge-original.jpg',1)

ret,thresh = cv.threshold(img,106,255,0)
print(ret)
contours,hierarchy = cv.findContours(thresh,1,2)


cnt = contours[0]
M = cv.moments(cnt)
print(M,len(contours))

area = cv.contourArea(cnt)
print(area)
epsilon = 0.1*cv.arcLength(cnt,True)
approx = cv.approxPolyDP(cnt,epsilon,True)

# =============================================================================
x,y,w,h = cv.boundingRect(cnt)
cv.rectangle(img2,(x,y),(x+w,y+h),(0,0,255),2)
# =============================================================================

# =============================================================================
x,y,w,h = cv.boundingRect(contours[1])
cv.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
# =============================================================================

hull = cv.convexHull(contours[0])
foot = []
for a in hull:
    if a[0][1]>100:
        foot.append(a)
print(foot)

rect = cv.minAreaRect(np.array(foot))
box = cv.boxPoints(rect)
box = np.int0(box)
cv.drawContours(img,[box],0,(0,0,255),2)

cv.drawContours(img2,foot,-1,(255,0,0),3)
x,y,w,h = cv.boundingRect(np.array(foot))
cv.rectangle(img2,(x,y),(x+w,y+h),(0,0,255),2)



cv.imshow("hehe",img2)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 106.0
# {'m00': 13617.5, 'm10': 2988220.6666666665, 'm01': 1547831.6666666665, 'm20': 667431248.0833333, 'm11': 356207719.7083333, 'm02': 237847998.0833333, 'm30': 151869164716.5, 'm21': 83442950535.31667, 'm12': 56129069507.416664, 'm03': 40553034160.200005, 'mu20': 11696880.34374988, 'mu11': 16551940.390951693, 'mu02': 61913878.87377864, 'mu30': 274704040.2243042, 'mu21': 315142802.2091098, 'mu12': 173017488.93320656, 'mu03': -556801561.5296631, 'nu20': 0.06307761721688135, 'nu11': 0.08925943751617245, 'nu02': 0.33388218373109796, 'nu30': 0.012694675004642681, 'nu21': 0.014563438713279926, 'nu12': 0.007995516885492441, 'nu03': -0.02573101895379861} 2
# 13617.5
# [array([[307, 197]], dtype=int32), array([[306, 201]], dtype=int32), array([[303, 207]], dtype=int32), array([[273, 215]], dtype=int32), array([[263, 217]], dtype=int32), array([[255, 217]], dtype=int32), array([[204, 207]], dtype=int32), array([[200, 206]], dtype=int32), array([[197, 203]], dtype=int32), array([[194, 196]], dtype=int32), array([[190, 185]], dtype=int32), array([[189, 182]], dtype=int32), array([[307, 188]], dtype=int32)]
